# %%
import seaborn as sns
import pandas as pd
iris=sns.load_dataset('iris')
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
sns.scatterplot(x='petal_length', y='petal_width', data=iris)
plt.title('Petal Length vs Petal Width')
plt.show()

# %%
print(iris.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='species', data=iris)
plt.title('Count plot of species')
plt.show()

# %%
sns.histplot(iris['sepal_length'], kde=True)
plt.title('Distribution of Sepal Length')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
iris['species'].value_counts().plot(kind='bar')
plt.title('Species count')
plt.show()

# %%
#map()applies a function to all items in an input list
numbers = [1, 2, 3, 4, 5]
squared = list(map(lambda x:x**2,numbers))
print("Squared:", squared)
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print("Even numbers:", even_numbers)
from functools import reduce
product = reduce(lambda x,y:x *y, numbers)
print("Product:", product)
# Out:
# Squared: [1, 4, 9, 16, 25]
# Even numbers: [2, 4]
# Product: 120

# %%
# Importing necessary library
import pandas as pd
# Read data from an existing file
file_path = "/mnt/data/auto-mpg.csv"
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[76], line 5
#       3 # Read data from an existing file
#       4 file_path = "/mnt/data/auto-mpg.csv"
# ----> 5 df = pd.read_csv(file_path)
#       6 # a. Read data from an existing file
#       7 print(df.head())
#
# ...

# %%
import pandas as pd
import numpy as np
Series_A = pd.Series([10, 20, 30, 40, 50])
Series_B = pd.Series([40, 50, 60, 70, 80])

# %%
not_common = pd.concat([Series_A, Series_B]).drop_duplicates(keep=False)
print(not_common)
# Out:
# 0    10
# 1    20
# 2    30
# 2    60
# 3    70
# 4    80
# dtype: int64

# %%
smallest_A = Series_A.min()
largest_A = Series_A.max()
print(f"Smallest in Series A: {smallest_A}")
print(f"Largest in Series A: {largest_A}")
# Out:
# Smallest in Series A: 10
# Largest in Series A: 50

# %%
sum_B = Series_B.sum()
print(f"Sum of Series B: {sum_B}")
# Out:
# Sum of Series B: 300

# %%
average_A = Series_A.mean()
print(f"Average of Series A: {average_A}")
# Out:
# Average of Series A: 30.0

# %%
median_B = Series_B.median()
print(f"Median of Series B: {median_B}")
# Out:
# Median of Series B: 60.0

# %%
13 question

# %%
import pandas as pd
data = {
 'First Name': ['Aryan', 'Rohan', 'Riya', 'Yash', 'Siddhanth'],
 'Last Name': ['Singh', 'Agarwal', 'Shah', 'Bhatia', 'Khanna'],
 'Type': ['Full-time Employee', 'Intern', 'Full-time Employee', 'Part-time Employee', 'Full-time Employee'],
 'Department': ['Administration', 'Technical', 'Administration', 'Technical', 'Management'],
 'YoE': [2, 1, 5, 3, 3],
 'Salary': [20000, 10000, 10000, 5000, 20000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   First Name Last Name                Type      Department  YoE  Salary
# 0      Aryan     Singh  Full-time Employee  Administration    2   20000
# 1      Rohan   Agarwal              Intern       Technical    1   10000
# 2       Riya      Shah  Full-time Employee  Administration    5   10000
# 3       Yash    Bhatia  Part-time Employee       Technical    3    5000
# 4  Siddhanth    Khanna  Full-time Employee      Management    3   20000

# %%
pivot_avg_salary = df.pivot_table(values='Salary', index='Type', aggfunc='mean')
print(pivot_avg_salary)
# Out:
#                           Salary
# Type
# Full-time Employee  16666.666667
# Intern              10000.000000
# Part-time Employee   5000.000000

# %%
pivot_sum_mean_salary = df.pivot_table(values='Salary', index='Type', aggfunc=['sum', 'mean', 'count'])
print(pivot_sum_mean_salary)
# Out:
#                       sum          mean  count
#                    Salary        Salary Salary
# Type
# Full-time Employee  50000  16666.666667      3
# Intern              10000  10000.000000      1
# Part-time Employee   5000   5000.000000      1

# %%
pivot_std_salary = df.pivot_table(values='Salary', aggfunc='std')
print(pivot_std_salary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 pivot_std_salary = df.pivot_table(values='Salary', aggfunc='std')
#       2 print(pivot_std_salary)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
# ...
